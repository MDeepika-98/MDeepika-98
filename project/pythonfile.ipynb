# %%
import numpy as np
import pandas as pd

# %%
hs = pd.read_csv('C:/Users/manik/Downloads/HomesForSale.csv')
hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   120 non-null    object
#  1   Price   120 non-null    int64
#  2   Size    120 non-null    int64
#  3   Beds    120 non-null    int64
#  4   Baths   120 non-null    float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 4.8+ KB

# %%
hs1=pd.read_csv('C:/Users/manik/OneDrive/Desktop/sales.csv')
hs1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datesold      120 non-null    object
#  1   postcode      120 non-null    int64
#  2   propertyType  120 non-null    object
#  3   Beds          120 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 3.9+ KB

# %%
new_column = ((hs['Size']*0.111))
hs.insert(3, 'Size in Yards', new_column)

# %%
hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          120 non-null    object
#  1   Price          120 non-null    int64
#  2   Size           120 non-null    int64
#  3   Size in Yards  120 non-null    float64
#  4   Beds           120 non-null    int64
#  5   Baths          120 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 5.8+ KB

# %%
new_column2 = ((hs['Price']/hs['Size']))
hs.insert(3, 'Price per sq.foot', new_column2)

# %%
hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              120 non-null    object
#  1   Price              120 non-null    int64
#  2   Size               120 non-null    int64
#  3   Price per sq.foot  120 non-null    float64
#  4   Size in Yards      120 non-null    float64
#  5   Beds               120 non-null    int64
#  6   Baths              120 non-null    float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 6.7+ KB

# %%
new_column3 = ((hs['Price']/hs['Size in Yards']))
hs.insert(5, 'Price per sq.yards', new_column3)

# %%
hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               120 non-null    object
#  1   Price               120 non-null    int64
#  2   Size                120 non-null    int64
#  3   Price per sq.foot   120 non-null    float64
#  4   Size in Yards       120 non-null    float64
#  5   Price per sq.yards  120 non-null    float64
#  6   Beds                120 non-null    int64
#  7   Baths               120 non-null    float64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 7.6+ KB

# %%
new_column4 = ((hs['Beds']+hs['Baths']))
hs.insert(8, 'Total Rooms', new_column4)

# %%
hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               120 non-null    object
#  1   Price               120 non-null    int64
#  2   Size                120 non-null    int64
#  3   Price per sq.foot   120 non-null    float64
#  4   Size in Yards       120 non-null    float64
#  5   Price per sq.yards  120 non-null    float64
#  6   Beds                120 non-null    int64
#  7   Baths               120 non-null    float64
#  8   Total Rooms         120 non-null    float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 8.6+ KB

# %%
hs.head(20)
# Out:
#    State  Price  Size  Price per sq.foot  Size in Yards  Price per sq.yards  \
# 0     CA    533  1589           0.335431        176.379            3.021902
# 1     CA    610  2008           0.303785        222.888            2.736801
# 2     CA    899  2380           0.377731        264.180            3.402983
# 3     CA    929  1868           0.497323        207.348            4.480390
# 4     CA    210  1360           0.154412        150.960            1.391097
# 5     CA    268  2131           0.125763        236.541            1.132996
# 6     CA   1095  2436           0.449507        270.396            4.049616
# 7     CA    699  1375           0.508364        152.625            4.579853
# 8     CA    729  2013           0.362146        223.443            3.262577
# 9     CA    700  1371           0.510576        152.181            4.599786
# 10    CA    145  1440           0.100694        159.840            0.907157
# ...

# %%
merge=pd.merge(hs,hs1)
merge.head(20)
# Out:
#    State  Price  Size  Price per sq.foot  Size in Yards  Price per sq.yards  \
# 0     CA    533  1589           0.335431        176.379            3.021902
# 1     CA    533  1589           0.335431        176.379            3.021902
# 2     CA    533  1589           0.335431        176.379            3.021902
# 3     CA    533  1589           0.335431        176.379            3.021902
# 4     CA    533  1589           0.335431        176.379            3.021902
# 5     CA    533  1589           0.335431        176.379            3.021902
# 6     CA    533  1589           0.335431        176.379            3.021902
# 7     CA    533  1589           0.335431        176.379            3.021902
# 8     CA    533  1589           0.335431        176.379            3.021902
# 9     CA    533  1589           0.335431        176.379            3.021902
# 10    CA    533  1589           0.335431        176.379            3.021902
# ...

# %%
merge.to_csv('C:/Users/manik/Downloads/New1_HomesForSale.csv')
